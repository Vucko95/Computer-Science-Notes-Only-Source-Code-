# %% [markdown]
# # Drawing Plots in Python

# %% [markdown]
# **Matplotlib** is a great data visualisation package that we can use in Python to draw data visualisations. In this notebook we will look at making basic data visualisation building blocks. Some of this material is based on an iPython notebook provided by Randal Olson, who does great visualsiation work. Visit http://www.randalolson.com/ for more.

# %% [markdown]
# Import Matplotlib, and note the use of the inline command to make vicualsiations work with iPython notebook.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Vertical bar charts
#
# **Purpose**: Comparing categories.
#
# **matplotlib function**: [`bar(left, height)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar)
#
# * `left`: The x coordinate(s) of the left sides of the bars.
#
# * `height`: The height(s) of the bars.

# %%
# Create a very simple dataset
years = np.arange(2012, 2015)
values = [2, 5, 9]

# Create the figure
plt.figure()

# Add the data
plt.bar(years, values)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars.
#
# * `edgecolor`: Set the color of the lines on the edges of the bars.
#
# * `width`: Set the width of the bars.
#
# * `align`: Set the alignment of the bars, e.g., center them on the x coordinate(s).
#
# * `label`: Set the label for the bar that will show up in the legend.

# %%
# Create a very simple dataset
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7, 6, 3]

# Create the figure
plt.figure()

# Plot the dataset as bars using display parameters
plt.bar(years - 0.2,
        category1_values,
        color='blue',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y1')

# Plot the dataset as bars using display parameters
plt.bar(years + 0.2,
        category2_values,
        color='orange',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y2')

# Add horizontal labels
plt.xticks(years, [str(year) for year in years])

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Horizontal bar charts
#
# **Purpose**: Comparing categories.
#
# **matplotlib function**: [`barh(bottom, width)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.barh)
#
# * `bottom`: The y coordinate(s) of the bars.
#
# * `width`: The width(s) of the bars.

# %%
# Create a simple dataset
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

# Create a figure
plt.figure()

# Plot the dataset as horizontal bars
plt.barh(np.arange(len(categories)), values)

# Add labels on vertical axis
plt.yticks(np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories])

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars.
#
# * `edgecolor`: Set the color of the lines on the edges of the bars.
#
# * `height`: Set the height of the bars.
#
# * `align`: Set the alignment of the bars, e.g., center them on the y coordinate(s).

# %%
# Create the dataset
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 12, 4, 2, 9]

# Create the figure
plt.figure()

# Plot the data as horizontal bars with parameters
plt.barh(-np.arange(len(categories)),
         values,
         color='blue',
         edgecolor='none',
         height=0.6,
         align='center')

# Add vertical axis labels
plt.yticks(-np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories])

# Show the plot
plt.show()

# %% [markdown]
# # Pie charts
#
# **Purpose**: Displaying a simple proportion.
#
# **matplotlib function**: [`pie(sizes)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)
#
# * `sizes`: The size of the wedges as either a fraction or number.

# %%
# Crete dataset
counts = [17, 14]

# Create the figure - note the size is symmetrical
plt.figure(figsize=(4, 4))

# Plot the datset as a pie
plt.pie(counts)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `colors`: Set the colors of the wedges.
#
# * `labels`: Set the labels of the wedges.
#
# * `startangle`: Set the angle that the wedges start at.
#
# * `autopct`: Set the percentage display format of the wedges.

# %%
# Create the dataset
counts = [17, 14]

# Create the figure - note the size is symmetrical
plt.figure(figsize=(4, 4))

# Plot the datset as a pie with parameters
plt.pie(counts,
        colors=['blue', 'orange'],
        labels=['Category A', 'Other categories'],
        startangle=90,
        autopct='%1.1f%%')

# Show the plot
plt.show()

# %% [markdown]
# # Histograms
#
# **Purpose**: Showing the spread of a data column.
#
# **matplotlib function**: [`hist(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist)
#
# * `x`: List of values to display the distribution of.

# %%
# Optional: 
# Setting the state of the pseudo-random number generator
# to a fixed value for reproducibility
np.random.seed(13)

# %%
# Create some simple data
column_data = np.random.normal(42, 3, 1000)

# Create a figure 
plt.figure()

# Plot the data aas a histogram
plt.hist(column_data)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars in the histogram.
#
# * `bins`: Set the number of bins to display in the histogram, or specify specific bins.
#
# * `normed`: Indicate whether the bins should display fractions instead of counts.

# %%
# Create some simple data
# column_data = np.random.normal(42, 3, 1000)

# Create a figure 
plt.figure()

# Plot the dataset as a histogram with parameters
plt.hist(column_data,
         color='red',
         bins=100)

# Show the plot
plt.show()

# %% [markdown]
# # Box plots
#
# **Purpose**: Summarize the distribution of a data column.
#
# **matplotlib function**: [`boxplot(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.boxplot)
#
# * `x`: List of values (or list of lists of values) to display the distribution of.

# %%
# Create some simple data
two_columns_data = [np.random.normal(57, 3, 1000),
                    np.random.normal(42, 7, 1000)]

# Create a figure 
plt.figure()

# Plot the datset as box plots
plt.boxplot(two_columns_data)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `labels`: Set the labels for the box plots.
#
# * `notch`: Indicate whether notches should be created around the median.
#
# * `bootstrap`: Indicate whether the notches around the median should be bootstrapped.

# %%
# Create some simple data
two_columns_data = [np.random.normal(57, 3, 1000),
                    np.random.normal(42, 7, 1000)]

# Create a figure 
plt.figure()

# Plot the datset as box plots
plt.boxplot(two_columns_data,
            labels=['A', 'B'],
            notch=True,
            bootstrap=10000)

# Show the plot
plt.show()

# %% [markdown]
# # Line plots
#
# **Purpose**: Showing trends in data -- usually time series data with many time points.
#
# **matplotlib function**: [`plot(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)
#
# * `x`: The x-coordinates of the lines or markers.
#
# * `y`: The y-coordinates of the lines or markers.

# %%
# Make a simple sin curve dataset
x = np.linspace(0, 20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

# Create the figure
plt.figure()

# Add the data sets
plt.plot(x, y1)
#plt.plot(x, y2)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the line.
#
# * `linestyle`: Set the line style, e.g., solid, dashed, or none.
#
# * `linewidth`: Set the line thickness.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or none.
#
# * `markersize`: Set the marker size.
#
# * `label`: Set the label for the line that will show up in the legend.

# %%
# Make a simple sin curve dataset
x = np.linspace(0, 20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

# Create the figure
plt.figure(figsize=(10, 5))

# Plot the datasets using display parameters
plt.plot(x,
         y1,
         color='black',
         linestyle='-',
         linewidth=2,
         marker='s',
         markersize=6,
         label='y1')

# Plot the datasets using display parameters
plt.plot(x,
         y2,
         color='gray',
         linestyle='--',
         linewidth=2,
         marker='^',
         markersize=6,
         label='y2')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Create a nice time series data frame
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
    
# Create the figure
plt.figure(figsize=(10, 5))

# Add the data sets
plt.plot(df.index, df["A"])
plt.plot(df.index, df["B"])
plt.plot(df.index, df["C"])
plt.plot(df.index, df["D"])

# Show the plot
plt.show()

# %% [markdown]
# # Scatter plots
#
# **Purpose**: Displaying relationships between variables.
#
# **matplotlib function**: [`scatter(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)
#
# * `x`, `y`: The values for the two variables.

# %%
# Create some simple data
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

# Create the figure
plt.figure()

# Plot the data as a scatter plot
plt.scatter(x, y)

# Show the plot
plt.show()

# %% [markdown]
# **Commonly used parameters**:
#
# * `c`: Set the color of the markers.
#
# * `s`: Set the size of the markers.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or squares.
#
# * `edgecolor`: Set the color of the lines on the edges of the markers.

# %%
# Create a simple dataset
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

# Creat ethe figure
plt.figure()

# Plot the data as a scatter plot
plt.scatter(x,
            y,
            c='red',
            s=40,
            marker='s',
            edgecolor='none')

# Show the plot
plt.show()

# %% [markdown]
# A **scatter plot matrix** or **SPLOM** is a nice way to create a set of scatter plots for a collection of variables. **pandas** has a fucntion, **scatter_matrix** to draw scatter plot matrices.

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
pd.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x110efbb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1110a4050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11111ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11118b0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11133add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1111a36d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110eefa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110d18ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x110bcfd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110a0aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1109badd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110874450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1102c1cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110a61b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11090c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110888350>]], dtype=object)
