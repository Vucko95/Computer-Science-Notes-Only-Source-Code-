# %% [markdown]
# # Underscore Conventions
# - single underscore: weak indicator that it should not be accessed outside the class.
#      - depends on programmer
#      - does not show up in tab completions
# - double underscore: hidden using name mangling

# %%
class EncapDemo():
    def __init__(self):
        self.v1 = 11
        self._v2 = 22
        self.__v3 = 33
        
    def incBy_v3(self, x):
        return x + self.__v3

# %%
ed = EncapDemo()

# %%
# Test tab completion on 'ed.'
ed.v1
# Out:
# 11

# %%
ed._v2
# Out:
# 22

# %%
# __v3 hidden by name mangling
ed.__v3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-06f0da62875e> in <module>()
# ----> 1 ed.__v3
#
# AttributeError: 'EncapDemo' object has no attribute '__v3'

# %%
ed._EncapDemo__v3
# Out:
# 33

# %%
ed.__dict__
# Out:
# {'_EncapDemo__v3': 33, '_v2': 22, 'v1': 11}

# %%
ed.incBy_v3(44)
# Out:
# 77
