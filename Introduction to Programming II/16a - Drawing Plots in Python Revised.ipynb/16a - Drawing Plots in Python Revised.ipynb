# %% [markdown]
# # Drawing Plots in Python

# %% [markdown]
# **Matplotlib** is a great data visualisation package that we can use in Python to draw data visualisations. In this notebook we will look at making basic data visualisation building blocks.

# %% [markdown]
# Import Matplotlib, and note the use of the inline command to make vicualsiations work with iPython notebook.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# To get plots to appear in our Jupyter notebook we need to use the following Jupyter "magic command"

# %%
# %matplotlib inline

# %% [markdown]
# We can also explictily pass a list of index values to the Series method so as to use a more intersting index. For example:

# %%
populations = pd.Series([1357000000, 1200000000, 321068000, 249900000, 249900000, 200400000, 191854000], 
                        ["China", "India", "United States", "Indonesia", "Qumar", "Brazil", "Pakistan"])
print(populations)
# Out:
# China            1357000000
# India            1200000000
# United States     321068000
# Indonesia         249900000
# Qumar             249900000
# Brazil            200400000
# Pakistan          191854000
# dtype: int64

# %% [markdown]
# ### Basic Statistical Visualisations

# %% [markdown]
# #### Bar chart

# %%
populations.plot(kind = "bar", \
                 title="National Populations")

# %% [markdown]
# #### Horizontal bar chart

# %%
populations.plot(kind = "barh", title="National Populations")

# %%
populations.plot(kind = "barh", \
                 title="National Populations", \
                 xlim = (0, 1500000000))

# %%
populations.plot(kind = "barh", \
                 title="National Populations", \
                 xlim = (0, 1500000000), \
                 grid=True)

# %%
populations.plot(kind = "barh", title="National Populations", \
                 xlim = (0, 1500000000), \
                 grid=True, 
                 xticks=(0, 500000000, 1000000000, 1500000000))

# %% [markdown]
# We can easily change the colours of the bars in a bar plot using the *color* attribute.

# %%
populations.plot(kind = "barh", \
                 title="National Populations", \
                 xlim = (0, 1500000000), \
                 grid=True, \
                 xticks=(0, 500000000, 1000000000, 1500000000), \
                 color = ['lemonchiffon', '#ff0000', 'b'])

# %% [markdown]
# Full list of named matplotlib colours is availabe [here](http://matplotlib.org/examples/color/named_colors.html)

# %%
populations.plot(kind = "barh", \
                 title="National Populations", \
                 xlim = (0, 1500000000), \
                 grid=True, xticks=(0, 500000000, 1000000000, 1500000000), \
                 color = 'lightskyblue')

# %% [markdown]
# Or we can give colours as RGB values in hex code

# %%
populations.plot(kind = "barh", title="National Populations", xlim = (0, 1500000000), grid=True, xticks=(0, 500000000, 1000000000, 1500000000), color = '#007700')

# %% [markdown]
# If we have a categorical series we first need to generate a frequency table before plotting abar chart

# %%
parties = ['FG', 'FF', 'IO', 'SF', 'Lab', 'AAA-PBP', 'SD', 'GP', 'RI']
votes = pd.Series(np.random.choice(parties, 100000, p=[0.25, 0.24, 0.18, 0.14, 0.066, 0.040, 0.035, 0.027, 0.022]))
print(votes)
# Out:
# 0             GP
# 1             FF
# 2             FG
# 3             FG
# 4             SF
# 5            Lab
# 6             FG
# 7        AAA-PBP
# 8             IO
# 9             IO
# 10            FG
# 11            FF
# 12            FF
# 13           Lab
# 14            FF
# 15            GP
# 16            SF
# 17            RI
# 18            FF
# 19            FF
# 20            FF
# 21            FF
# 22            SD
# 23            IO
# 24            SF
# 25            SF
# 26            SF
# 27            FG
# 28            SF
# 29            FG
#           ...
# 99970         FF
# 99971         IO
# 99972         FG
# 99973        Lab
# 99974         FG
# 99975         RI
# 99976         IO
# 99977         FF
# 99978        Lab
# 99979         SF
# 99980         FG
# 99981         IO
# 99982         FG
# 99983         FG
# 99984         SF
# 99985         FF
# 99986         IO
# 99987         FG
# 99988         FF
# 99989         SF
# 99990         IO
# 99991         FF
# 99992         FF
# 99993         GP
# 99994         SF
# 99995         FG
# 99996         FF
# 99997         FF
# 99998         IO
# 99999         IO
# dtype: object

# %%
votes.plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b09a98d4bbd5> in <module>()
# ----> 1 votes.plot(kind="bar")
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
#    3599                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3600                            **kwds)
#    3601     __call__.__doc__ = plot_series.__doc__
#    3602
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2672                  yerr=yerr, xerr=xerr,
#    2673                  label=label, secondary_y=secondary_y,
# -> 2674                  **kwds)
#    2675
#    2676
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in generate(self)
#    1039     def generate(self):
#    1040         self._args_adjust()
# -> 1041         self._compute_plot_data()
#    1042         self._setup_subplots()
#    1043         self._make_plot()
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in _compute_plot_data(self)
#    1148         if is_empty:
#    1149             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1150                             'plot'.format(numeric_data.__class__.__name__))
#    1151
#    1152         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
vc = votes.value_counts()
vc = vc/vc.sum()
vc
# Out:
# FG         0.24901
# FF         0.24163
# IO         0.18042
# SF         0.13981
# Lab        0.06615
# AAA-PBP    0.03963
# SD         0.03468
# GP         0.02672
# RI         0.02195
# dtype: float64

# %%
vc.plot(kind = 'bar')

# %% [markdown]
# #### Pie chart

# %%
vc.plot(kind = "pie", title="National Populations")

# %%
vc.plot(kind = "pie", \
                 title="Votes", \
                figsize=(6,6))

# %%
vc.plot(kind = "pie", \
                 title="Votes", \
                 figsize=(6,6), \
                 colormap = "Accent")

# %% [markdown]
# #### Histograms

# %% [markdown]
# Generate some data for histograms

# %%
mu = 165
sigma = 20
heights = pd.Series(np.random.normal(mu, sigma, 1000))
heights
# Out:
# 0      167.449387
# 1      128.666704
# 2      126.293974
# 3      176.191534
# 4      192.765263
# 5      183.972744
# 6      157.774037
# 7      143.927299
# 8      149.878892
# 9      164.860486
# 10     183.737902
# 11     217.245146
# 12     140.216395
# 13     175.231280
# 14     157.670092
# 15     151.254633
# 16     163.544328
# 17     113.410912
# 18     146.357587
# 19     148.982299
# 20     130.105235
# 21     148.669203
# 22     180.358034
# 23     167.223582
# 24     145.704224
# 25     175.470009
# 26     163.155891
# 27     169.389082
# 28     150.957119
# 29     185.030235
#           ...
# 970    157.213940
# 971    176.194280
# 972    171.467117
# 973    155.772447
# 974    175.163257
# 975    153.500729
# 976    151.900402
# 977    173.156351
# 978    156.326740
# 979    176.796884
# 980    181.260901
# 981    177.663879
# 982    173.845393
# 983    166.724607
# 984    162.537330
# 985    151.962819
# 986    121.268144
# 987    181.767220
# 988    125.423429
# 989    130.106061
# 990    150.152745
# 991    166.278071
# 992    182.093936
# 993    171.262060
# 994    162.288047
# 995    171.009238
# 996    162.904804
# 997    182.854107
# 998    163.479021
# 999    178.260177
# dtype: float64

# %%
heights.plot(kind="hist", \
             title = "Student Heights", \
             xlim = (0, 250))

# %% [markdown]
# #### Box plots

# %%
heights.plot(kind="box", title = "Student Heights")

# %% [markdown]
# #### Density plots

# %%
heights.plot(kind="kde", title = "Student Heights", ylim = (0, 0.03))

# %% [markdown]
# #### Line plots

# %% [markdown]
# Generate some time series data for line and area plots.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2015', periods=1000))
ts = ts.cumsum()

# %%
ts.plot(kind = "line", title = "Price")

# %% [markdown]
# #### Area Plot

# %%
ts.plot(kind = "area", title = "Price", stacked= False)

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Scatter plots are great for displaying relationships between variables.

# %% [markdown]
# Load a dataset so we can look at some scatter plots.

# %%
PAYE_Fraud = pd.read_csv("PAYE_Fraud.csv")
PAYE_Fraud.head()
# Out:
#    CustomerID Title FirstInitial    Surname   Age          Location  \
# 0           1  Mrs.            A      Boyle  29.0            Dublin
# 1           2  Mrs.            L   McIntosh  41.0  Leinster (Other)
# 2           3  Mrs.            T     Graham  45.0           Munster
# 3           4  Mrs.            P     Miller  49.0  Leinster (Other)
# 4           5   Mr.            A  Henderson  44.0  Leinster (Other)
#
#   OccupationType       Industry  YearsInCurrentEmployment  \
# 0       Employed        Finance                      3.41
# 1       Employed      Transport                     12.41
# 2       Employed  Public Sector                     26.52
# 3  Self-Employed   Professional                     21.76
# 4       Employed         Retail                     12.02
#
#    NumPreviousEmployments  TotalIncome  TaxableIncome   TaxPaid  \
# 0                       4     29189.63       26266.72   5253.34
# 1                       2     28817.90       27107.49   5421.50
# 2                       2     33295.90       32034.02   6406.80
# 3                       5     65901.91       60494.01  17914.54
# 4                       1     66955.36       57323.67  16614.70
#
#    EffectiveTaxRate UnionSubs Fraud
# 0          0.179973        No    No
# 1          0.188130       Yes    No
# 2          0.192420       Yes    No
# 3          0.271836        No    No
# 4          0.248146        No    No

# %%
plt.figure(figsize=(10, 10))
plt.scatter(PAYE_Fraud["TaxPaid"], PAYE_Fraud["YearsInCurrentEmployment"])

# %%
plt.figure(figsize=(10, 10))
plt.scatter(PAYE_Fraud["TaxPaid"], PAYE_Fraud["YearsInCurrentEmployment"], s = PAYE_Fraud["TotalIncome"]/1000)

# %%
plt.figure(figsize=(10, 10))
colMap = {"Employed":"Red", 'Self-Employed':"Green", "Casual":"Blue"}
plt.scatter(PAYE_Fraud["EffectiveTaxRate"], PAYE_Fraud["TaxableIncome"], c = PAYE_Fraud["OccupationType"].map(colMap), alpha=0.2)

# %% [markdown]
# A **scatter plot matrix** or **SPLOM** is a nice way to create a set of scatter plots for a collection of variables. **pandas** has a fucntion, **scatter_matrix** to draw scatter plot matrices.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(PAYE_Fraud[["YearsInCurrentEmployment", "NumPreviousEmployments", "TotalIncome", "TaxableIncome"]], alpha=0.2, figsize=(10, 10), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112cff1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112edf0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f475f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f98d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11300a080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11300a0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1130c5ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1131238d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11318ba20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1131e9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113250b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132a5550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113313b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11332e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1133d8898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113443ba8>]], dtype=object)

# %% [markdown]
# A **hexbin** plot is an alternative to a simple scatter plot that solves a problem that arises when datasets are very large. We use the **seaborn** package to draw hexbin plots.

# %%
import seaborn as sns
from scipy.stats import kendalltau # Used for performing a correlation test between varaibles in hexbin
sns.set(style="ticks") # Makes for nicer looking histograms

# %%
sns.jointplot(PAYE_Fraud["TaxPaid"], PAYE_Fraud["YearsInCurrentEmployment"], kind="hex", stat_func=kendalltau, color="#4CB391")

# %%
sns.jointplot(PAYE_Fraud["EffectiveTaxRate"], PAYE_Fraud["TaxableIncome"], kind="hex", stat_func=kendalltau, color="red")

# %% [markdown]
# ### matplotlib Styles

# %% [markdown]
# We can change styles in matplotlib easily

# %%
matplotlib.style.use('ggplot')
populations.plot(kind = "barh", title="National Populations")

# %%
matplotlib.style.use('fivethirtyeight')
populations.plot(kind = "barh", title="National Populations")

# %%
matplotlib.style.use('seaborn-colorblind')
populations.plot(kind = "barh", title="National Populations")

# %%
plt.xkcd()
populations.plot(kind = "barh", title="National Populations")

# %% [markdown]
# ### Saving Plots

# %% [markdown]
# We can easily save plots we generate in our notebooks.

# %%
ts.plot(kind = "line", title = "Price")
plt.savefig('lineplot.pdf')

# %%
populations.plot(kind = "barh", title="National Populations")
plt.savefig('barplot.pdf')
